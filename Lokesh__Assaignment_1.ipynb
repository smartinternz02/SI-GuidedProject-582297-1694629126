# %%
import pandas as pd
import numpy as np
import random
a=['lokesh','manish','aashika','tharun','varun','mani','sunil']
data={
    'Maths':np.random.randint(0,100,size=7),
    'phy':np.random.randint(0,100,size=7),
    'che':np.random.randint(0,100,size=7),
    'Student':[random.choice(a) for _ in range(7)]
}
df=pd.DataFrame(data)
df
# Out:
#    Maths  phy  che  Student
# 0     22   90   11    varun
# 1     17   85   30   manish
# 2     20   15   12   tharun
# 3     84    1   87   lokesh
# 4     94   95   48   tharun
# 5     32   36   57     mani
# 6     70   37   35  aashika

# %%
#Task 2

# %%
df.rename(columns={'Maths':'Random value 1','phy':'Random value 2','che':'Random value 3','Student':'Random value 4'},inplace=True)
df
# Out:
#    Random value 1  Random value 2  Random value 3 Random value 4
# 0              22              90              11          varun
# 1              17              85              30         manish
# 2              20              15              12         tharun
# 3              84               1              87         lokesh
# 4              94              95              48         tharun
# 5              32              36              57           mani
# 6              70              37              35        aashika

# %%
#Task3

# %%
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3
# count        7.000000        7.000000        7.000000
# mean        48.428571       51.285714       40.000000
# std         33.095101       38.361067       26.807959
# min         17.000000        1.000000       11.000000
# 25%         21.000000       25.500000       21.000000
# 50%         32.000000       37.000000       35.000000
# 75%         77.000000       87.500000       52.500000
# max         94.000000       95.000000       87.000000

# %%
#Task4

# %%
df.isnull().any()
# Out:
# Random value 1    False
# Random value 2    False
# Random value 3    False
# Random value 4    False
# dtype: bool

# %%
data=df.dtypes

# %%
data
# Out:
# Random value 1     int64
# Random value 2     int64
# Random value 3     int64
# Random value 4    object
# dtype: object

# %%
#Task5

# %%
#location method

# %%
df.loc[:,['Random value 2','Random value 3']]
# Out:
#    Random value 2  Random value 3
# 0              90              11
# 1              85              30
# 2              15              12
# 3               1              87
# 4              95              48
# 5              36              57
# 6              37              35

# %%
#using index location method

# %%
df.iloc[:,[1,2]]
# Out:
#    Random value 2  Random value 3
# 0              90              11
# 1              85              30
# 2              15              12
# 3               1              87
# 4              95              48
# 5              36              57
# 6              37              35
